# %%
import pandas as pd
import yfinance as yf

# %%
nba = pd.ExcelFile('./raw_data/nba.xlsx')

# %%
nba.sheet_names
# Out:
# ['Team Revenue - Total',
#  'Team Revenue - Ticket',
#  'Operating Income',
#  'NBA Revenue',
#  'Metros',
#  'Season Data',
#  'Dates',
#  'Data Sources']

# %%
total = nba.parse('Team Revenue - Total')
total = total.rename({'Unnamed: 0': 'Team'}, axis=1)
total = total.set_index('Team')
total = total.unstack().reset_index()  
total = total.rename({'level_0': 'Year', 0: 'Total Revenue'}, axis=1)

# %%
ticket = nba.parse('Team Revenue - Ticket')
ticket = ticket.rename({'Unnamed: 0': 'Team'}, axis=1)
ticket = ticket.set_index('Team')
ticket = ticket.unstack().reset_index()  
ticket = ticket.rename({'level_0': 'Year', 0: 'Ticket Revenue'}, axis=1)

# %%
oi = nba.parse('Operating Income')
oi = oi.rename({'Unnamed: 0': 'Team'}, axis=1)
oi = oi.set_index('Team')
oi = oi.unstack().reset_index()  
oi = oi.rename({'level_0': 'Year', 0: 'Operating Income'}, axis=1)

# %%
total = pd.merge(total, ticket)
total = pd.merge(total, oi)

# %%
total
# Out:
#      Year                Team  Total Revenue  Ticket Revenue  Operating Income
# 0    2011       Atlanta Hawks            109           26.30               -15
# 1    2011      Boston Celtics            146           52.70                 8
# 2    2011       Brooklyn Nets             89           23.30               -24
# 3    2011   Charlotte Hornets            101           19.50               -26
# 4    2011       Chicago Bulls            185           59.00                59
# ..    ...                 ...            ...             ...               ...
# 325  2021    Sacramento Kings            192            0.00                25
# 326  2021   San Antonio Spurs            205            2.37                39
# 327  2021     Toronto Raptors            194            1.62                 2
# 328  2021           Utah Jazz            262            5.33                96
# 329  2021  Washington Wizards            213            0.00                15
#
# [330 rows x 5 columns]

# %%
pops = nba.parse('Metros')
pops = pops[['Team',
             'Population, 2020',
             'Population, 2010',
             'Per Capita Income, 2010',
             'Per Capita Income, 2020']]

# %%
total = pd.merge(total, pops)
total['Population'] = None
total['Income'] = None

# %%
total.loc[total['Year'] <= 2020, 'Population'] = total.loc[total['Year'] <= 2020, 'Population, 2010']
total.loc[total['Year'] > 2020, 'Population'] = total.loc[total['Year'] > 2020, 'Population, 2020']

total.loc[total['Year'] <= 2020, 'Income'] = total.loc[total['Year'] <= 2020, 'Per Capita Income, 2010']
total.loc[total['Year'] > 2020, 'Income'] = total.loc[total['Year'] > 2020, 'Per Capita Income, 2020']

# %%
total = total.drop(['Population, 2020',
                    'Population, 2010',
                    'Per Capita Income, 2010',
                    'Per Capita Income, 2020'], axis=1)

# %%
seasons = nba.parse('Season Data')
seasons
# Out:
#                        Team   Age   W   L  Attend.  Attend./G  Playoffs  \
# 0             Orlando Magic  27.9  59  23   715901      17461       1.0
# 1       Cleveland Cavaliers  28.0  61  21   843042      20562       1.0
# 2                 Utah Jazz  25.6  53  29   794512      19378       1.0
# 3         San Antonio Spurs  28.7  50  32   741676      18090       1.0
# 4             Atlanta Hawks  26.5  53  29   678375      16546       1.0
# ..                      ...   ...  ..  ..      ...        ...       ...
# 385         Detroit Pistons  23.6  23  59   663556      16184       0.0
# 386           Orlando Magic  23.3  22  60   622881      15192       0.0
# 387   Oklahoma City Thunder  22.4  24  58   595112      14515       0.0
# 388         Houston Rockets  24.1  20  62   638977      15585       0.0
# 389  Portland Trail Blazers  25.6  27  55   705608      17210       0.0
#
#      Conference Semifinals  Conference Finals  Finals  Championship  Year
# 0                      1.0                  1       0           0.0  2010
# 1                      1.0                  0       0           0.0  2010
# 2                      1.0                  0       0           0.0  2010
# 3                      1.0                  0       0           0.0  2010
# 4                      1.0                  0       0           0.0  2010
# ..                     ...                ...     ...           ...   ...
# 385                    0.0                  0       0           0.0  2022
# 386                    0.0                  0       0           0.0  2022
# 387                    0.0                  0       0           0.0  2022
# 388                    0.0                  0       0           0.0  2022
# 389                    0.0                  0       0           0.0  2022
#
# [390 rows x 12 columns]

# %%
data = pd.merge(total, seasons, how='left')

# %%
data['nGames'] = data['W'] + data['L']

# %%
data['WP'] = data['W'] / data['nGames']

# %%
data = data.drop(['W', 'L'], axis=1)

# %%
data = data.rename({'Total Revenue': 'Revenue',
                    'Ticket Revenue': 'Ticket',
                    'Operating Income': 'OI',
                    'Attend.': 'Attendance',
                    'Attend./G': 'APG',
                    'Conference Semifinals': 'CSF',
                    'Conference Finals': 'CF'}, axis=1)

# %%
data['Revenue'] = data['Revenue'] * 82 / data['nGames']
data['Ticket'] = data['Ticket'] * 82 / data['nGames']

# %%
data = data.drop(['Attendance', 'nGames'], axis=1)

# %%
dates = nba.parse('Dates')

# %%
pend2start = []
pstart2start = []
newyear2start = []

# %%
for i in range(dates.shape[0]):
    start = dates.loc[i, 'Previous End']
    end = dates.loc[i, 'Start']
    temp_data = yf.download('SPY', start = start.date(), end = end.date())
    pend2start.append((temp_data.values[-1,3] - temp_data.values[0,0]) / temp_data.values[0,0])
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
for i in range(dates.shape[0]):
    start = dates.loc[i, 'Previous Start']
    end = dates.loc[i, 'Start']
    temp_data = yf.download('SPY', start = start.date(), end = end.date())
    pstart2start.append((temp_data.values[-1,3] - temp_data.values[0,0]) / temp_data.values[0,0])
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
for i in range(dates.shape[0]):
    start = dates.loc[i, 'BoY']
    end = dates.loc[i, 'Start']
    temp_data = yf.download('SPY', start = start.date(), end = end.date())
    newyear2start.append((temp_data.values[-1,3] - temp_data.values[0,0]) / temp_data.values[0,0])
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
dates['MPC1'] = pend2start
dates['MPC2'] = pstart2start
dates['MPC3'] = newyear2start

# %%
data = pd.merge(data,
                dates[['Season', 'MPC1', 'MPC2', 'MPC3']],
                how='left',
                left_on='Year',
                right_on='Season')

# %%
data = data.drop('Season', axis=1)

# %%
social = pd.read_csv('./Raw Data/social.csv')

# %%
data = pd.merge(data, social[['Team', 'Year', 'Followers', 'Franch_Val']], how='left', on=['Team', 'Year'])

# %%
data
# Out:
#      Year                Team     Revenue     Ticket  OI Population Income  \
# 0    2011       Atlanta Hawks  109.000000  26.300000 -15    5286728  38774
# 1    2012       Atlanta Hawks  123.000000  24.972727 -19    5286728  38774
# 2    2013       Atlanta Hawks  119.000000  23.600000  -4    5286728  38774
# 3    2014       Atlanta Hawks  133.000000  22.900000  15    5286728  38774
# 4    2015       Atlanta Hawks  142.000000  27.800000   7    5286728  38774
# ..    ...                 ...         ...        ...  ..        ...    ...
# 325  2017  Washington Wizards  222.000000  55.100000  21    5636232  58429
# 326  2018  Washington Wizards  255.000000  56.800000  34    5636232  58429
# 327  2019  Washington Wizards  269.000000  60.900000  55    5636232  58429
# 328  2020  Washington Wizards  263.083333  48.516667  39    5636232  58429
# 329  2021  Washington Wizards  242.583333   0.000000  15    6385162  76110
#
#       Age    APG  Playoffs  CSF  CF  Finals  Championship        WP      MPC1  \
# 0    27.4  15649       1.0  1.0   0       0           0.0  0.536585  0.057178
# 1    27.9  15200       1.0  0.0   0       0           0.0  0.606061 -0.011729
# 2    27.1  15126       1.0  0.0   0       0           0.0  0.536585  0.073273
# 3    27.5  14231       1.0  0.0   0       0           0.0  0.463415  0.127583
# 4    27.8  17412       1.0  1.0   1       0           0.0  0.731707  0.057637
# ..    ...    ...       ...  ...  ..     ...           ...       ...       ...
# 325  26.0  17003       1.0  1.0   0       0           0.0  0.597561  0.029068
# 326  26.9  18032       1.0  0.0   0       0           0.0  0.524390  0.048032
# 327  26.5  17448       0.0  0.0   0       0           0.0  0.390244 -0.003957
# 328  25.1  16647       0.0  0.0   0       0           0.0  0.347222  0.042464
# 329  26.6    533       1.0  0.0   0       0           0.0  0.472222  0.052261
#
#          MPC2      MPC3  Followers Franch_Val
# 0    0.109035  0.056332       0.20        295
# 1    0.070195 -0.002525       0.35        270
# 2    0.120314  0.106371       0.52        316
# 3    0.242369  0.214458       1.20        425
# 4    0.110570  0.066203       1.78        825
# ..        ...       ...        ...        ...
# 325  0.042144  0.071824       2.29      1,000
# 326  0.189165  0.134421       2.38      1,350
# 327  0.075109  0.024492       2.55      1,550
# 328  0.084562  0.219571       5.74      1,750
# 329  0.223834  0.136985       6.31      1,925
#
# [330 rows x 20 columns]

# %%
data.to_csv('cleaned.csv')
